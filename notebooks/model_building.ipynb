# %% [markdown]
# Build a regression model.

# %%
import pandas as pd
import statsmodels.api as sm

# %%
pd.set_option('display.max_rows', None)

# %%
# Reset display options to default values
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# %%
df_chosen_var = pd.read_csv('../data/df_chosen_var.csv')
df_chosen_var
# Out:
#      number_of_bikes_avail  average_distance_fs  average_price_fs  \
# 0                       10                490.3          1.888889
# 1                        5                390.6          2.000000
# 2                       20                454.5          1.600000
# 3                        4                655.9          2.111111
# 4                       21                753.3          1.250000
# ..                     ...                  ...               ...
# 155                     22                473.7          1.600000
# 156                      6                294.2          1.666667
# 157                      2                212.7          2.111111
# 158                      3                286.6          1.500000
# 159                     20                305.6          1.888889
#
#      average_popularity_fs  average_rating_fs  average_distance_yelp  \
# 0                 0.970151           8.710000             540.318381
# ...

# %%
# Removing 1 row with a NaN value 
df_chosen_var_cleaned = df_chosen_var.dropna()
df_chosen_var_cleaned
# Out:
#      number_of_bikes_avail  average_distance_fs  average_price_fs  \
# 0                       10                490.3          1.888889
# 1                        5                390.6          2.000000
# 2                       20                454.5          1.600000
# 3                        4                655.9          2.111111
# 4                       21                753.3          1.250000
# ..                     ...                  ...               ...
# 155                     22                473.7          1.600000
# 156                      6                294.2          1.666667
# 157                      2                212.7          2.111111
# 158                      3                286.6          1.500000
# 159                     20                305.6          1.888889
#
#      average_popularity_fs  average_rating_fs  average_distance_yelp  \
# 0                 0.970151           8.710000             540.318381
# ...

# %%
# Create a function that will run a regression model with the x variables as inputs
def regression_modeling(x_vars):
    X = df_chosen_var_cleaned[x_vars]
    y = df_chosen_var_cleaned['number_of_bikes_avail']

    # Add a constant to the model
    X = sm.add_constant(X)

    # Create the model
    model = sm.OLS(y, X)

    # Fit the model
    results = model.fit()

    return results.summary()

# %%
# First model with all the x variables from Foursquare dataset
x_variables = ['average_distance_fs', 'average_price_fs', 'average_popularity_fs', 'average_rating_fs']
print(regression_modeling(x_variables))
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     number_of_bikes_avail   R-squared:                       0.008
# Model:                               OLS   Adj. R-squared:                 -0.018
# Method:                    Least Squares   F-statistic:                    0.3038
# Date:                   Wed, 13 Dec 2023   Prob (F-statistic):              0.875
# Time:                           20:16:02   Log-Likelihood:                -507.18
# No. Observations:                    159   AIC:                             1024.
# Df Residuals:                        154   BIC:                             1040.
# Df Model:                              4
# Covariance Type:               nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
# Second model with all the x variables from Yelp dataset
x_variables = ['average_distance_yelp', 'average_price_yelp', 'average_popularity_yelp', 'average_rating_yelp']
print(regression_modeling(x_variables))
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     number_of_bikes_avail   R-squared:                       0.059
# Model:                               OLS   Adj. R-squared:                  0.035
# Method:                    Least Squares   F-statistic:                     2.430
# Date:                   Wed, 13 Dec 2023   Prob (F-statistic):             0.0501
# Time:                           20:17:13   Log-Likelihood:                -502.94
# No. Observations:                    159   AIC:                             1016.
# Df Residuals:                        154   BIC:                             1031.
# Df Model:                              4
# Covariance Type:               nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Provide model output and an interpretation of the results.

# %% [markdown]
# # Stretch

# %% [markdown]
# How can you turn the regression model into a classification model?
